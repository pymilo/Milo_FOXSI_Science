# %% [markdown]
# # FOXSI-3 Targets Analysis

# %% [markdown]
# ### Milo Buitrago-Casas
# Space Sciences Laboratory <br>
# UC Berkeley

# %% [markdown]
# I assume we launched on time, i.e. at 17:21UT on Sept 7, 2018.<br/>
# Observations started 110 seconds after launched.<br/><br/>
# Target exposure time: <br/>
# 1 (AR): 120 seconds<br/>
# 2 (NP): 30 seconds<br/>
# 3 (QS): 150 seconds<br/>
# 4 (AR): 60 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches
from datetime import datetime
import urllib.request
import sunpy.map
from sunpy.physics.differential_rotation import diffrot_map
import astropy.units as u
import ipywidgets as widgets

# %% [markdown]
# ### FOXSI-3 Time

# %%
TFOXSI = datetime(2018,9,7,11,21)
#dt = ((TFOXSI - datetime.today()).total_seconds()/86400.) *u.day

# %% [markdown]
# ## Target 1

# %% [markdown]
# T1i = 2018-09-07T17:22:50<br/>
# T1f = 2018-09-07T17:24:50<br/>
# **Reading files:**

# %% [markdown]
# **Init**

# %%
dir_path = '/Volumes/Pandora/FOXSI/AIA-FOXSI3/'
file094T1i = dir_path+'aia.lev1_euv_12s.2018-09-07T172249Z.94.image_lev1.fits'
file171T1i = dir_path+'aia.lev1_euv_12s.2018-09-07T172246Z.171.image_lev1.fits'
file211T1i = dir_path+'aia.lev1_euv_12s.2018-09-07T172247Z.211.image_lev1.fits'

T1i094 = sunpy.map.Map(file094T1i)
T1i171 = sunpy.map.Map(file171T1i)
T1i211 = sunpy.map.Map(file211T1i)
TempMapT1i = sunpy.map.Map(file171T1i)
TempMapT1i.data[:] = T1i211.data[:]/-120 + T1i171.data[:]/-450

# %% [markdown]
# **Mid**

# %%
file094T1m = dir_path+'aia.lev1_euv_12s.2018-09-07T172349Z.94.image_lev1.fits'
file171T1m = dir_path+'aia.lev1_euv_12s.2018-09-07T172346Z.171.image_lev1.fits'
file211T1m = dir_path+'aia.lev1_euv_12s.2018-09-07T172347Z.211.image_lev1.fits'

T1m094 = sunpy.map.Map(file094T1m)
T1m171 = sunpy.map.Map(file171T1m)
T1m211 = sunpy.map.Map(file211T1m)
TempMapT1m = sunpy.map.Map(file171T1m)
TempMapT1m.data[:] = T1m211.data[:]/-120 + T1m171.data[:]/-450

# %% [markdown]
# **Final**

# %%
file094T1f = dir_path+'aia.lev1_euv_12s.2018-09-07T172449Z.94.image_lev1.fits'
file171T1f = dir_path+'aia.lev1_euv_12s.2018-09-07T172446Z.171.image_lev1.fits'
file211T1f = dir_path+'aia.lev1_euv_12s.2018-09-07T172447Z.211.image_lev1.fits'

T1f094 = sunpy.map.Map(file094T1f)
T1f171 = sunpy.map.Map(file171T1f)
T1f211 = sunpy.map.Map(file211T1f)
TempMapT1f = sunpy.map.Map(file171T1f)
TempMapT1f.data[:] = T1f211.data[:]/-120 + T1f171.data[:]/-450

# %% [markdown]
# ## Target 3

# %% [markdown]
# T3i = 2018-09-07T17:25:20<br/>
# T3m = 2018-09-07T17:26:35<br/>
# T3f = 2018-09-07T17:27:50<br/>
# **Reading files:**

# %% [markdown]
# **Init**

# %%
file094T3i = dir_path+'aia.lev1_euv_12s.2018-09-07T172525Z.94.image_lev1.fits'
file171T3i = dir_path+'aia.lev1_euv_12s.2018-09-07T172522Z.171.image_lev1.fits'
file211T3i = dir_path+'aia.lev1_euv_12s.2018-09-07T172523Z.211.image_lev1.fits'

T3i094 = sunpy.map.Map(file094T3i)
T3i171 = sunpy.map.Map(file171T3i)
T3i211 = sunpy.map.Map(file211T3i)
TempMapT3i = sunpy.map.Map(file171T3i)
TempMapT3i.data[:] = T3i211.data[:]/-120 + T3i171.data[:]/-450

# %% [markdown]
# **Mid**

# %%
file094T3m = dir_path+'aia.lev1_euv_12s.2018-09-07T172637Z.94.image_lev1.fits'
file171T3m = dir_path+'aia.lev1_euv_12s.2018-09-07T172634Z.171.image_lev1.fits'
file211T3m = dir_path+'aia.lev1_euv_12s.2018-09-07T172635Z.211.image_lev1.fits'

T3m094 = sunpy.map.Map(file094T3m)
T3m171 = sunpy.map.Map(file171T3m)
T3m211 = sunpy.map.Map(file211T3m)
TempMapT3m = sunpy.map.Map(file171T3m)
TempMapT3m.data[:] = T3m211.data[:]/-120 + T3m171.data[:]/-450

# %% [markdown]
# **Final**

# %%
file094T3f = dir_path+'aia.lev1_euv_12s.2018-09-07T172749Z.94.image_lev1.fits'
file171T3f = dir_path+'aia.lev1_euv_12s.2018-09-07T172746Z.171.image_lev1.fits'
file211T3f = dir_path+'aia.lev1_euv_12s.2018-09-07T172747Z.211.image_lev1.fits'

T3f094 = sunpy.map.Map(file094T3f)
T3f171 = sunpy.map.Map(file171T3f)
T3f211 = sunpy.map.Map(file211T3f)
TempMapT3f = sunpy.map.Map(file171T3f)
TempMapT3f.data[:] = T3f211.data[:]/-120 + T3f171.data[:]/-450

# %% [markdown]
# ## Target 4

# %% [markdown]
# **Final**

# %%
file094T4f = dir_path+'aia.lev1_euv_12s.2018-09-07T172849Z.94.image_lev1.fits'
file171T4f = dir_path+'aia.lev1_euv_12s.2018-09-07T172846Z.171.image_lev1.fits'
file211T4f = dir_path+'aia.lev1_euv_12s.2018-09-07T172847Z.211.image_lev1.fits'

T4f094 = sunpy.map.Map(file094T4f)
T4f171 = sunpy.map.Map(file171T4f)
T4f211 = sunpy.map.Map(file211T4f)
TempMapT4f = sunpy.map.Map(file171T4f)
TempMapT4f.data[:] = T4f211.data[:]/-120 + T4f171.data[:]/-450

# %% [markdown]
# ## Interact to chose Targets :

# %%
ang = [-82.5000, -75.0000, 67.5000, 75.0000, -97.5000, -90.0000, 60.0000]  ## Detector angles

fig, ax = plt.subplots(figsize=(10,10));
#T4f094.plot(vmin=2,title='AIA 94 Target4 AR - 2018-09-07T172849')
#T4f094.draw_limb()
TempMapT4f.plot(vmin=-10,title='AIA Fe XVIII Target4 AR - 2018-09-07T172846')
TempMapT4f.draw_limb(color='black')


def fov(cdte,x,y):
    ax.patches, ax.texts = [], []
    ## Pos0 - Si
    l = 990
    mx = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[0]-45)) + 1)
    my = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[0]-135)) + 1)
    rect = patches.Rectangle((x-l/2+mx,y-l/2+my),990,990,angle=ang[0],linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
    
    ## Pos1 PhoEniX
    lphx = 1161.7
    lphy = 435.6
    rect = patches.Rectangle((x-lphx/2,y-lphy/2),lphx,lphy,linewidth=1,edgecolor='orange',facecolor='none')
    ax.add_patch(rect)
    for i in range (-2,3):
        rect = patches.Rectangle((x-lphx/2,y-lphy*(1/2+i)),lphx,lphy,linewidth=.7,edgecolor='orange',facecolor='none',linestyle='dashed')
        ax.add_patch(rect) 
        
    ## Pos2 - Si
    l = 990
    mx = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[2]-45)) + 1)
    my = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[2]-135)) + 1)
    rect = patches.Rectangle((x-l/2+mx,y-l/2+my),990,990,angle=ang[2],linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)

    ## Pos4 - Si
    l = 990
    mx = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[4]-45)) + 1)
    my = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[4]-135)) + 1)
    rect = patches.Rectangle((x-l/2+mx,y-l/2+my),990,990,angle=ang[4],linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)
    
    ## Pos6 - Si
    l = 990
    mx = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[6]-45)) + 1)
    my = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[6]-135)) + 1)
    rect = patches.Rectangle((x-l/2+mx,y-l/2+my),990,990,angle=ang[6],linewidth=1,edgecolor='r',facecolor='none')
    ax.add_patch(rect)

    if cdte=='Pos3 CdTe-FEC07':
        ## Pos3 CdTe
        l = 792
        mx = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[3]-45)) + 1)
        my = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[3]-135)) + 1)
        rect = patches.Rectangle((x-l/2+mx,y-l/2+my),l,l,angle=ang[3],linewidth=1,edgecolor='y',facecolor='none')
        ax.add_patch(rect)
        ## bad strips
        dsx = [0,674.5,730.2]
        ldx = [61.9,12.4,61.9]
        for d,ld in zip(dsx,ldx):
            dx = d * np.cos(np.deg2rad(ang[3]))
            dy = d * np.sin(np.deg2rad(ang[3]))
            rect = patches.Rectangle((x-l/2+mx+dx,y-l/2+my+dy),ld,l,angle=ang[3],linewidth=1,edgecolor='y',facecolor='y',alpha=0.3)
            ax.add_patch(rect)
        dsy = [0,185.6,507.4,563.1,581.7,618.8,649.7,668.3,717.8]
        ldy = [61.9,12.4,24.8,12.4,24.7,12.4,12.4,12.4,74.3]
        for d,ld in zip(dsy,ldy):
            dx = d * np.sin(np.deg2rad(ang[3]))
            dy = d * np.cos(np.deg2rad(ang[3]))
            rect = patches.Rectangle((x-l/2+mx-dx,y-l/2+my+dy),l,ld,angle=ang[3],linewidth=1,edgecolor='y',facecolor='y',alpha=0.3)
            ax.add_patch(rect)    
            
    elif cdte=='Pos5 CdTe-FEC09':
        ## Pos5 CdTe
        l = 792
        mx = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[5]-45)) + 1)
        my = l/2 * ( np.sqrt(2) * np.sin(np.deg2rad(ang[5]-135)) + 1)
        rect = patches.Rectangle((x-l/2+mx,y-l/2+my),l,l,angle=ang[5],linewidth=1,edgecolor='y',facecolor='none')
        ax.add_patch(rect)
        ## bad strips
        dsx = [0,99,383.6,550.7,581.7,665.9,730.2]
        ldx = [61.9,18.6,31,6.2,6.2,8.6,61.9]
        for d,ld in zip(dsx,ldx):
            dx = d * np.cos(np.deg2rad(ang[5]))
            dy = d * np.sin(np.deg2rad(ang[5]))
            rect = patches.Rectangle((x-l/2+mx+dx,y-l/2+my+dy),ld,l,angle=ang[5],linewidth=1,edgecolor='y',facecolor='y',alpha=0.3)
            ax.add_patch(rect)
        dsy = [0,136.1,148.5,272.3,396,420.8,519.8,594,730.2]
        ldy = [68.1,6.2,6.2,12.3,6.2,12.4,18.5,12.4,62]
        for d,ld in zip(dsy,ldy):
            dx = d * np.sin(np.deg2rad(ang[5]))
            dy = d * np.cos(np.deg2rad(ang[5]))
            rect = patches.Rectangle((x-l/2+mx-dx,y-l/2+my+dy),l,ld,angle=ang[5],linewidth=1,edgecolor='y',facecolor='y',alpha=0.3)
            ax.add_patch(rect)
    ## Arrow
    #arr = patches.Arrow(430, 90, 90, -90,linewidth=1,color='blue')
    #ax.add_patch(arr)
    #ax.relim()
    #ax.autoscale()
    display(fig)
# Out:
# /Users/Kamilobu/anaconda3/lib/python3.5/site-packages/sunpy/map/mapbase.py:1736: Warning: This map is not properly oriented. Plot axes may be incorrect
#   Warning)

# %%
offx = 430
offy = 40
length = 300
step = 10
widgets.interact(fov, cdte=['Pos3 CdTe-FEC07','Pos5 CdTe-FEC09'], x=(-length+offx,length+offx,step), y=(-length+offy,length+offy,step));
# Out:
# interactive(children=(Dropdown(description='cdte', options=('Pos3 CdTe-FEC07', 'Pos5 CdTe-FEC09'), value='Pos3…

# %% [markdown]
# # List of Targets :

# %%
Ftarget = {'cen1': {'xy':(430, 40.0),   'col':'white'},
           'cen2': {'xy':(0.0, 650.0), 'col':'red'},
           'cen3': {'xy':(-650.0, 40.0),  'col':'blue'},
           'cen4': {'xy':(0.0, -650.0),   'col':'yellow'},
           'cen5': {'xy':(430.0, 40.0),  'col':'magenta'}
          }

# %%
fig, ax = plt.subplots(figsize=(10,10));
rot094.plot(vmin=0,title='FOXSI3 Targets on top of AIA 94 rotated to '+TFOXSI.strftime("%Y-%m-%d_%H:%M MDT"))
rot094.draw_limb()


for key in Ftarget:
    x,y = Ftarget[key]['xy']
    rect = patches.Rectangle((x-480,y-480),960,960,linewidth=1.5,edgecolor=Ftarget[key]['col'],facecolor='none')
    ax.add_patch(rect)
    ax.text(x-457, y-462, key, fontsize=12,color='black')
    ax.text(x-460, y-460, key, fontsize=12,color=Ftarget[key]['col'])
# Out:
# /Users/Kamilobu/anaconda3/lib/python3.6/site-packages/sunpy/map/mapbase.py:669: Warning: Missing metadata for heliographic longitude: assuming longitude of 0 degrees
#   lon=self.heliographic_longitude,
# /Users/Kamilobu/anaconda3/lib/python3.6/site-packages/sunpy/map/mapbase.py:1740: Warning: WCSAxes not being used as the axes object for this plot. Plots may have expected behaviour
#   Warning)

# %%
tobs = [120, 30,150, 30, 30] ## seconds

# %%
np.sqrt(450**2+200**2)/60
# Out:
# 8.207381501496753

# %%
np.sqrt(90**2+90**2)/60
# Out:
# 2.121320343559643
